# %%
import os
import cv2
import numpy  as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt

# %%
# Function to load and preprocess images
def load_and_preprocess_images(directory, label):
    img_list = []
    label_list = []
    for filename in os.listdir(directory):
        if filename.endswith((".jpg",".jpeg",".png")):
            img_path = os.path.join(directory, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, (img_width, img_height))
            img = img / 255.0  # Normalize pixel values to be between 0 and 1
            img_list.append(img)
            label_list.append(label)
    return img_list, label_list

# Function to apply image augmentation (flip-Rotate)
def Flip_augmentation(images_list, labels_list): 
    images = []
    labels = []
    for img, label in zip(images_list, labels_list):
        flipped_img = np.fliplr(img)        # Flip the image
        images.append(flipped_img)
        labels.append(label)
    return images, labels

def Rotation_augmentation(images_list, labels_list, Angel): 
    images = []
    labels = []
    for img, label in zip(images_list, labels_list):
        rotated_img = np.rot90(img, Angel // 90)   # Rotate the image
        images.append(rotated_img)
        labels.append(label)
    return images, labels

# %%
classes = ['NORMAL', 'COVID']
#Import Train Data
Train_dataset_dir = r'C:\Users\shahrooz\Desktop\Neural Network\HW2\Code\train-dataset' #Path to dataset
Train_covid_dir = os.path.join(Train_dataset_dir, 'COVID')
Train_normal_dir = os.path.join(Train_dataset_dir, 'NORMAL')
# Define the image dimensions
img_height, img_width, img_channel = 150, 150 , 3
# Define the lists to store images and labels
Train_images = []
Train_labels = []
# Load and preprocess original COVID images (label = 1)
Train_covid_images, Train_covid_labels = load_and_preprocess_images(Train_covid_dir, 1)
# Load and preprocess original NORMAL images (label = 0)
Train_normal_images, Train_normal_labels = load_and_preprocess_images(Train_normal_dir, 0)
# Append original images and labels to the lists
Train_images.extend(Train_covid_images + Train_normal_images)
Train_labels.extend(Train_covid_labels + Train_normal_labels)

# %%
# Image informations
images = []                   # Save Train images list  
labels = []                   # Save Train labels list 
images = Train_images.copy()         # Save Train images list  
labels = Train_labels.copy()         # Save Train labels list 
print("Shape of images array:", np.array(images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array:", np.array(labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(images[0])
plt.title(classes[labels[0]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array: (148, 150, 150, 3)
# Shape of labels array: (148,)

# %%
# Flip Augmentation : 
flipped_images, flipped_labels = Flip_augmentation(Train_images, Train_labels)
images.extend(flipped_images)
labels.extend(flipped_labels)
print("Shape of images array (Main + flipped):", np.array(images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array (Main + flipped):", np.array(labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(images[148])
plt.title(classes[labels[148]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array (Main + flipped): (296, 150, 150, 3)
# Shape of labels array (Main + flipped): (296,)

# %%
# 90rotation Augmentation : 
rotate90_images, rotate90_labels = Rotation_augmentation(Train_images, Train_labels,90)
images.extend(rotate90_images)
labels.extend(rotate90_labels)
print("Shape of images array (Main + flipped + rotated):", np.array(images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array (Main + flipped + rotated):", np.array(labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(images[296])
plt.title(classes[labels[296]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array (Main + flipped + rotated): (444, 150, 150, 3)
# Shape of labels array (Main + flipped + rotated): (444,)

# %%
# 180rotation Augmentation : 
rotate180_images, rotate180_labels = Rotation_augmentation(Train_images, Train_labels,180)
images.extend(rotate180_images)
labels.extend(rotate180_labels)
print("Shape of images array (Main + flipped + rotated):", np.array(images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array (Main + flipped + rotated):", np.array(labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(images[444])
plt.title(classes[labels[444]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array (Main + flipped + rotated): (592, 150, 150, 3)
# Shape of labels array (Main + flipped + rotated): (592,)

# %%
# 270rotation Augmentation : 
rotate270_images, rotate270_labels = Rotation_augmentation(Train_images, Train_labels,270)
images.extend(rotate270_images)
labels.extend(rotate270_labels)
print("Shape of images array (Main + flipped + rotated):", np.array(images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array (Main + flipped + rotated):", np.array(labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(images[592])
plt.title(classes[labels[592]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array (Main + flipped + rotated): (740, 150, 150, 3)
# Shape of labels array (Main + flipped + rotated): (740,)

# %%
Input_images = np.array(images)     # Convert lists to NumPy arrays
Input_labels = np.array(labels)     # Convert lists to NumPy arrays
print("Shape of first list of input images:", np.array(Input_images).shape)     # Display the shape of the input arrays
print("Shape of first list of input labels:", np.array(Input_labels).shape)     # Display the shape of the input arrays
# Out:
# Shape of first list of input images: (740, 150, 150, 3)
# Shape of first list of input labels: (740,)

# %%
validation_split = 0.15          # Define the training-validation split ratio (e.g., 85-15 split)
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(Input_images,Input_labels, test_size=validation_split, random_state=24)
print("Shape of train images :", X_train.shape)
print("Shape of train labels :", y_train.shape)
print("Shape of validation images :", X_val.shape) 
print("Shape of validation labels :", y_val.shape)
# Define batch size and number of epochs
batch_size = 32
epochs = 50
# Out:
# Shape of train images : (629, 150, 150, 3)
# Shape of train labels : (629,)
# Shape of validation images : (111, 150, 150, 3)
# Shape of validation labels : (111,)

# %%
# Define Model
# Clear the previous model
tf.keras.backend.clear_session()
# Define CNN model
model = models.Sequential()
# Input layer
model.add(layers.Input(shape=(150, 150, 3)))
# Layer 1: Convolutional layer with 64 filters, 3x3 kernel size
model.add(layers.Conv2D(64, (3, 3), input_shape=(150, 150, 3), padding='same'))
# Layer 2: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 3: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 4: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 5: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 6: Convolutional layer with 64 filters, 3x3 kernel size
model.add(layers.Conv2D(64, (3, 3), padding='same'))
# Layer 7: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 8: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 9: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 10: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 11: Convolutional layer with 128 filters, 3x3 kernel size
model.add(layers.Conv2D(128, (3, 3), padding='same'))
# Layer 12: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 13: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 14: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 15: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 16: Convolutional layer with 128 filters, 3x3 kernel size
model.add(layers.Conv2D(128, (3, 3), padding='same'))
# Layer 17: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 18: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 19: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 20: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 21: Convolutional layer with 256 filters, 3x3 kernel size
model.add(layers.Conv2D(256, (3, 3), padding='same'))
# Layer 22: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 23: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 24: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 25: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 26: Convolutional layer with 256 filters, 3x3 kernel size
model.add(layers.Conv2D(256, (3, 3), padding='same'))
# Layer 27: MaxPooling layer with 2x2 pooling size
model.add(layers.MaxPooling2D((2, 2)))
# Layer 28: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 29: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 30: Dropout layer with 20% dropout rate
model.add(layers.Dropout(0.2))
# Layer 31: Flattening layer
model.add(layers.Flatten())
# Layer 32: Dense layer with 512 neurons and ReLU activation
model.add(layers.Dense(512, activation='relu'))
# Layer 33: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 34: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 35: Dense layer with 256 neurons and ReLU activation
model.add(layers.Dense(256, activation='relu'))
# Layer 36: BatchNormalization layer
model.add(layers.BatchNormalization(axis=-1))
# Layer 37: Activation layer with ReLU function
model.add(layers.Activation('relu'))
# Layer 38: Output layer with 1 neuron and sigmoid activation for binary classification
model.add(layers.Dense(1, activation='sigmoid'))
# Display the model summary to check the structure
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 75, 75, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 75, 75, 64)        0
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 37, 37, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 37, 37, 64)        0
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 18, 18, 128)       0
#
#  dropout_2 (Dropout)         (None, 18, 18, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 9, 9, 128)        512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 9, 9, 128)         0
#
#  dropout_3 (Dropout)         (None, 9, 9, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 9, 9, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4, 4, 256)         0
#
#  dropout_4 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 256)         590080
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  dropout_5 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,808,449
# Trainable params: 1,805,121
# Non-trainable params: 3,328
# _________________________________________________________________

# %%
#Train model
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Set the learning rate for the Adam optimizer
learning_rate = 0.01  
# Create an Adam optimizer with the specified learning rate
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Compile the model with the customized Adam optimizer
model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# Define a ModelCheckpoint callback to save the best model during training
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
history = model.fit(X_train, y_train,epochs=epochs,batch_size=batch_size,validation_data=(X_val, y_val),callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 20/20 [==============================] - 41s 2s/step - loss: 0.7723 - accuracy: 0.7202 - val_loss: 113.3996 - val_accuracy: 0.5135
# Epoch 2/50
# 20/20 [==============================] - 37s 2s/step - loss: 0.4030 - accuracy: 0.8108 - val_loss: 15.4249 - val_accuracy: 0.4865
# Epoch 3/50
# 20/20 [==============================] - 36s 2s/step - loss: 0.2672 - accuracy: 0.9157 - val_loss: 0.9922 - val_accuracy: 0.5946
# Epoch 4/50
# 20/20 [==============================] - 38s 2s/step - loss: 0.1570 - accuracy: 0.9444 - val_loss: 1.1665 - val_accuracy: 0.6486
# Epoch 5/50
# 20/20 [==============================] - 38s 2s/step - loss: 0.1230 - accuracy: 0.9523 - val_loss: 5.0811 - val_accuracy: 0.6036
# Epoch 6/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.0675 - accuracy: 0.9857 - val_loss: 7.2180 - val_accuracy: 0.5676
# Epoch 7/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.0725 - accuracy: 0.9746 - val_loss: 6.4266 - val_accuracy: 0.5676
# Epoch 8/50
# 20/20 [==============================] - 43s 2s/step - loss: 0.0858 - accuracy: 0.9762 - val_loss: 5.6531 - val_accuracy: 0.6847
# Epoch 9/50
# 20/20 [==============================] - 39s 2s/step - loss: 0.0848 - accuracy: 0.9762 - val_loss: 1.8132 - val_accuracy: 0.6667
# Epoch 10/50
# 20/20 [==============================] - 56s 3s/step - loss: 0.0777 - accuracy: 0.9698 - val_loss: 3.0359 - val_accuracy: 0.7477
# Epoch 11/50
# 20/20 [==============================] - 49s 2s/step - loss: 0.0596 - accuracy: 0.9857 - val_loss: 5.8934 - val_accuracy: 0.5946
# Epoch 12/50
# 20/20 [==============================] - 49s 2s/step - loss: 0.0427 - accuracy: 0.9889 - val_loss: 2.7593 - val_accuracy: 0.6937
# Epoch 13/50
# 20/20 [==============================] - 50s 3s/step - loss: 0.0498 - accuracy: 0.9825 - val_loss: 1.2439 - val_accuracy: 0.8378
# Epoch 14/50
# 20/20 [==============================] - 48s 2s/step - loss: 0.0546 - accuracy: 0.9857 - val_loss: 0.1843 - val_accuracy: 0.9640
# Epoch 15/50
# 20/20 [==============================] - 51s 3s/step - loss: 0.0315 - accuracy: 0.9873 - val_loss: 1.0150 - val_accuracy: 0.8198
# Epoch 16/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 5.9406 - val_accuracy: 0.5766
# Epoch 17/50
# 20/20 [==============================] - 37s 2s/step - loss: 0.0402 - accuracy: 0.9873 - val_loss: 2.1869 - val_accuracy: 0.7658
# Epoch 18/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.0312 - accuracy: 0.9921 - val_loss: 1.0410 - val_accuracy: 0.8378
# Epoch 19/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.0351 - accuracy: 0.9841 - val_loss: 0.0607 - val_accuracy: 0.9910
# Epoch 20/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 1.7349 - val_accuracy: 0.7477
# Epoch 21/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.3819 - val_accuracy: 0.7928
# Epoch 22/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.0062 - accuracy: 0.9968 - val_loss: 0.1765 - val_accuracy: 0.9640
# Epoch 23/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.0262 - accuracy: 0.9905 - val_loss: 1.8956 - val_accuracy: 0.7297
# Epoch 24/50
# 20/20 [==============================] - 43s 2s/step - loss: 0.0520 - accuracy: 0.9857 - val_loss: 0.7136 - val_accuracy: 0.8649
# Epoch 25/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0357 - accuracy: 0.9905 - val_loss: 0.0711 - val_accuracy: 0.9820
# Epoch 26/50
# 20/20 [==============================] - 49s 2s/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.7523 - val_accuracy: 0.8829
# Epoch 27/50
# 20/20 [==============================] - 48s 2s/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.0985 - val_accuracy: 0.9730
# Epoch 28/50
# 20/20 [==============================] - 40s 2s/step - loss: 0.0178 - accuracy: 0.9921 - val_loss: 0.3023 - val_accuracy: 0.9369
# Epoch 29/50
# 20/20 [==============================] - 41s 2s/step - loss: 0.0207 - accuracy: 0.9936 - val_loss: 0.3311 - val_accuracy: 0.9279
# Epoch 30/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0181 - accuracy: 0.9952 - val_loss: 0.7449 - val_accuracy: 0.8649
# Epoch 31/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.8927 - val_accuracy: 0.8378
# Epoch 32/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0204 - accuracy: 0.9952 - val_loss: 0.6524 - val_accuracy: 0.8649
# Epoch 33/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.0149 - accuracy: 0.9921 - val_loss: 0.3947 - val_accuracy: 0.9459
# Epoch 34/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0290 - accuracy: 0.9873 - val_loss: 0.4627 - val_accuracy: 0.9369
# Epoch 35/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.5196 - val_accuracy: 0.9099
# Epoch 36/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.3670 - val_accuracy: 0.9279
# Epoch 37/50
# 20/20 [==============================] - 50s 3s/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0919 - val_accuracy: 0.9640
# Epoch 38/50
# 20/20 [==============================] - 51s 3s/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0993 - val_accuracy: 0.9550
# Epoch 39/50
# 20/20 [==============================] - 53s 3s/step - loss: 0.0034 - accuracy: 0.9984 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 49s 2s/step - loss: 0.0309 - accuracy: 0.9936 - val_loss: 1.4001 - val_accuracy: 0.8018
# Epoch 41/50
# 20/20 [==============================] - 41s 2s/step - loss: 0.0313 - accuracy: 0.9825 - val_loss: 5.3397 - val_accuracy: 0.6396
# Epoch 42/50
# 20/20 [==============================] - 41s 2s/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0810 - val_accuracy: 0.9640
# Epoch 43/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.0100 - accuracy: 0.9952 - val_loss: 0.0795 - val_accuracy: 0.9459
# Epoch 44/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.0505 - accuracy: 0.9857 - val_loss: 0.1736 - val_accuracy: 0.9369
# Epoch 45/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.0130 - accuracy: 0.9984 - val_loss: 0.3310 - val_accuracy: 0.9369
# Epoch 46/50
# 20/20 [==============================] - 43s 2s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9640
# Epoch 47/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 36s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
#Import Test Data
test_dataset_dir = r'C:\Users\shahrooz\Desktop\Neural Network\HW2\Code\test-dataset' #Path to dataset
test_covid_dir = os.path.join(test_dataset_dir, 'COVID')
test_normal_dir = os.path.join(test_dataset_dir, 'NORMAL')
# Define the lists to store images and labels
test_images = []
test_labels = []
# Load and preprocess test COVID images (label = 1)
test_covid_images, test_covid_labels = load_and_preprocess_images(test_covid_dir, 1)
# Load and preprocess test NORMAL images (label = 0)
test_normal_images, test_normal_labels = load_and_preprocess_images(test_normal_dir, 0)
# Append original images and labels to the lists
test_images.extend(test_covid_images + test_normal_images)
test_labels.extend(test_covid_labels + test_normal_labels)
print("Shape of images array:", np.array(test_images).shape)     # Display the shape of the arrays before first augmentation
print("Shape of labels array:", np.array(test_labels).shape)     # Display the shape of the arrays before first augmentation
plt.imshow(test_images[0])
plt.title(classes[labels[0]])
plt.axis("Off");
plt.show()
# Out:
# Shape of images array: (40, 150, 150, 3)
# Shape of labels array: (40,)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
X_test = np.array(test_images)     # Convert lists to NumPy arrays
y_test = np.array(test_labels)     # Convert lists to NumPy arrays
model_final = tf.keras.models.load_model('best_model.h5')

# Make predictions on the test set
y_pred = model_final.predict(X_test)
y_pred_binary = np.round(y_pred)  # Assuming your output is binary

# Convert predictions and true labels to 1D arrays
y_pred_flat = y_pred_binary.flatten()
y_test_flat = y_test.flatten()

# Calculate Accuracy
accuracy = accuracy_score(y_test_flat, y_pred_flat)
print("Accuracy:", accuracy)

# Calculate Precision
precision = precision_score(y_test_flat, y_pred_flat)
print("Precision:", precision)

# Calculate Recall (Sensitivity)
recall = recall_score(y_test_flat, y_pred_flat)
print("Sensitivity (Recall):", recall)

# Calculate Specificity
tn, fp, fn, tp = confusion_matrix(y_test_flat, y_pred_flat).ravel()
specificity = tn / (tn + fp)
print("Specificity:", specificity)

# Calculate F1 Score
f1 = f1_score(y_test_flat, y_pred_flat)
print("F1 Score:", f1)
# Out:
# 2/2 [==============================] - 2s 228ms/step
# Accuracy: 0.95
# Precision: 0.95
# Sensitivity (Recall): 0.95
# Specificity: 0.95
# F1 Score: 0.9500000000000001

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Calculate the confusion matrix
cm = confusion_matrix(y_test_flat, y_pred_flat)
# Plot the confusion matrix as a heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted 0', 'Predicted 1'], 
            yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import seaborn as sns
#       2 from sklearn.metrics import confusion_matrix
#       3 # Calculate the confusion matrix
#
# ModuleNotFoundError: No module named 'seaborn'
